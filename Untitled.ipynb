# %%
import pandas as pd

# %%
## Solana blocks data

# %%
blocks_data = pd.read_json("https://api.flipsidecrypto.com/api/v2/queries/4318342a-1816-4170-9d33-f9e391f62aa7/data/latest")
blocks_data.head()
# Out:
#      AMOUNT AUTHORITY BLOCKCHAIN   BLOCK_ID          BLOCK_TIMESTAMP  \
# 0  0.000007      None     solana  112579093  2021-12-21 10:51:37.000
# 1  0.000003      None     solana  112654416  2021-12-21 23:03:17.000
# 2  0.000004      None     solana  112561084  2021-12-21 08:10:31.000
# 3  0.000015      None     solana  112642067  2021-12-21 21:09:15.000
# 4  0.000005      None     solana  112610823  2021-12-21 16:06:17.000
#
#                                     DESTINATION EVENT_TYPE  INDEX  \
# 0  7ivguYMpnUBMboByJbKc7z31fJMg2pXYQ4nNPziWLchZ   transfer      1
# 1  3WaqdAUFHTfQ5LihkfLt4NzASebp4SEMBpdT1tbowSa2   transfer      1
# 2  8Q9Kdp1b9GQh5qmc8fYesGkfAZMMw8uF3ButvZ1p78fY   transfer      1
# 3  6FKvsq4ydWFci6nGq9ckbjYMtnmaqAoatz5c9XWjiDuS   transfer      0
# 4  4k7tCcpCq67P1p34MVYe5k6vtNAFbQqVo1xYXtTDCQPD   transfer      1
#
#               INGESTED_AT POSTTOKENBALANCES PRETOKENBALANCES  \
# 0 2021-12-21 10:54:40.463                []               []
# ...

# %%
# Solana transfers data

# %%
transfers_data = pd.read_json("https://api.flipsidecrypto.com/api/v2/queries/4318342a-1816-4170-9d33-f9e391f62aa7/data/latest")
transfers_data.head()
# Out:
#      AMOUNT AUTHORITY BLOCKCHAIN   BLOCK_ID          BLOCK_TIMESTAMP  \
# 0  0.000007      None     solana  112579093  2021-12-21 10:51:37.000
# 1  0.000003      None     solana  112654416  2021-12-21 23:03:17.000
# 2  0.000004      None     solana  112561084  2021-12-21 08:10:31.000
# 3  0.000015      None     solana  112642067  2021-12-21 21:09:15.000
# 4  0.000005      None     solana  112610823  2021-12-21 16:06:17.000
#
#                                     DESTINATION EVENT_TYPE  INDEX  \
# 0  7ivguYMpnUBMboByJbKc7z31fJMg2pXYQ4nNPziWLchZ   transfer      1
# 1  3WaqdAUFHTfQ5LihkfLt4NzASebp4SEMBpdT1tbowSa2   transfer      1
# 2  8Q9Kdp1b9GQh5qmc8fYesGkfAZMMw8uF3ButvZ1p78fY   transfer      1
# 3  6FKvsq4ydWFci6nGq9ckbjYMtnmaqAoatz5c9XWjiDuS   transfer      0
# 4  4k7tCcpCq67P1p34MVYe5k6vtNAFbQqVo1xYXtTDCQPD   transfer      1
#
#               INGESTED_AT POSTTOKENBALANCES PRETOKENBALANCES  \
# 0 2021-12-21 10:54:40.463                []               []
# ...
